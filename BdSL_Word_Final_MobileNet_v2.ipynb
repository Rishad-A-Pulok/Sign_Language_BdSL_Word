# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishad-A-Pulok/Sign_Language_BdSL_Word/blob/main/BdSL_Word_Final_MobileNet_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2

from tensorflow import keras
from tensorflow.keras import models,layers
from tensorflow.keras.models import Sequential
from keras import backend as K
from keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.applications import resnet
from keras.applications.vgg16 import VGG16
from keras.models import Model

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# !unzip "/content/drive/MyDrive/Sign Language Project/BdSL_Word.zip"
# Out:
# Archive:  /content/drive/MyDrive/Sign Language Project/BdSL_Word.zip
#    creating: Word/
#    creating: Word/Color/
#   inflating: Word/Color/color (1).jpg
#   inflating: Word/Color/color (10).jpg
#   inflating: Word/Color/color (11).jpg
#   inflating: Word/Color/color (12).jpg
#   inflating: Word/Color/color (13).jpg
#   inflating: Word/Color/color (14).jpg
#   inflating: Word/Color/color (15).jpg
#   inflating: Word/Color/color (16).jpg
#   inflating: Word/Color/color (17).jpg
#   inflating: Word/Color/color (18).jpg
#   inflating: Word/Color/color (19).jpg
#   inflating: Word/Color/color (2).jpg
#   inflating: Word/Color/color (20).jpg
#   inflating: Word/Color/color (21).jpg
#   inflating: Word/Color/color (22).jpg
#   inflating: Word/Color/color (23).jpg
#   inflating: Word/Color/color (24).jpg
#   inflating: Word/Color/color (25).jpg
#   inflating: Word/Color/color (26).jpg
#   inflating: Word/Color/color (27).jpg
#   inflating: Word/Color/color (28).jpg
#   inflating: Word/Color/color (29).jpg
#   inflating: Word/Color/color (3).jpg
#   inflating: Word/Color/color (30).jpg
#   inflating: Word/Color/color (31).jpg
#   inflating: Word/Color/color (32).jpg
#   inflating: Word/Color/color (33).jpg
#   inflating: Word/Color/color (34).jpg
#   inflating: Word/Color/color (35).jpg
#   inflating: Word/Color/color (36).jpg
#   inflating: Word/Color/color (37).jpg
#   inflating: Word/Color/color (38).jpg
#   inflating: Word/Color/color (39).jpg
#   inflating: Word/Color/color (4).jpg
#   inflating: Word/Color/color (40).jpg
#   inflating: Word/Color/color (41).jpg
#   inflating: Word/Color/color (42).jpg
#   inflating: Word/Color/color (43).jpg
#   inflating: Word/Color/color (44).jpg
#   inflating: Word/Color/color (45).jpg
#   inflating: Word/Color/color (46).jpg
#   inflating: Word/Color/color (47).jpg
#   inflating: Word/Color/color (48).jpg
#   inflating: Word/Color/color (49).jpg
#   inflating: Word/Color/color (5).jpg
#   inflating: Word/Color/color (50).jpg
#   inflating: Word/Color/color (51).jpg
#   inflating: Word/Color/color (52).jpg
#   inflating: Word/Color/color (53).jpg
#   inflating: Word/Color/color (54).jpg
#   inflating: Word/Color/color (55).jpg
#   inflating: Word/Color/color (56).jpg
#   inflating: Word/Color/color (57).jpg
#   inflating: Word/Color/color (58).jpg
#   inflating: Word/Color/color (59).jpg
#   inflating: Word/Color/color (6).jpg
#   inflating: Word/Color/color (60).jpg
#   inflating: Word/Color/color (61).jpg
#   inflating: Word/Color/color (62).jpg
#   inflating: Word/Color/color (63).jpg
#   inflating: Word/Color/color (64).jpg
#   inflating: Word/Color/color (65).jpg
#   inflating: Word/Color/color (66).jpg
#   inflating: Word/Color/color (67).jpg
#   inflating: Word/Myself/myself (8).jpg
#   inflating: Word/Myself/myself (80).jpg
#   inflating: Word/Myself/myself (81).jpg
#   inflating: Word/Myself/myself (82).jpg
#   inflating: Word/Myself/myself (83).jpg
#   inflating: Word/Myself/myself (84).jpg
#   inflating: Word/Myself/myself (85).jpg
#   inflating: Word/Myself/myself (86).jpg
#   inflating: Word/Myself/myself (87).jpg
#   inflating: Word/Myself/myself (88).jpg
#   inflating: Word/Myself/myself (89).jpg
#   inflating: Word/Myself/myself (9).jpg
#   inflating: Word/Myself/myself (90).jpg
#   inflating: Word/Myself/myself (91).jpg
#   inflating: Word/Myself/myself (92).jpg
#   inflating: Word/Myself/myself (93).jpg
#   inflating: Word/Myself/myself (94).jpg
#   inflating: Word/Myself/myself (95).jpg
#   inflating: Word/Myself/myself (96).jpg
#   inflating: Word/Myself/myself (97).jpg
#   inflating: Word/Myself/myself (98).jpg
#   inflating: Word/Myself/myself (99).jpg
#    creating: Word/Promise/
#   inflating: Word/Promise/promise (1).jpg
#   inflating: Word/Promise/promise (10).jpg
#   inflating: Word/Promise/promise (11).jpg
#   inflating: Word/Promise/promise (12).jpg
#   inflating: Word/Promise/promise (13).jpg
#   inflating: Word/Promise/promise (14).jpg
#   inflating: Word/Promise/promise (15).jpg
#   inflating: Word/Promise/promise (16).jpg
#   inflating: Word/Promise/promise (17).jpg
#   inflating: Word/Promise/promise (18).jpg
#   inflating: Word/Promise/promise (19).jpg
#   inflating: Word/Promise/promise (2).jpg
#   inflating: Word/Promise/promise (20).jpg
#   inflating: Word/Promise/promise (21).jpg
#   inflating: Word/Promise/promise (22).jpg
#   inflating: Word/Promise/promise (23).jpg
#   inflating: Word/Promise/promise (24).jpg
#   inflating: Word/Promise/promise (25).jpg
#   inflating: Word/Promise/promise (26).jpg
#   inflating: Word/Promise/promise (27).jpg
#   inflating: Word/Promise/promise (28).jpg
#   inflating: Word/Promise/promise (29).jpg
#   inflating: Word/Promise/promise (3).jpg
#   inflating: Word/Promise/promise (30).jpg
#   inflating: Word/Promise/promise (31).jpg
#   inflating: Word/Promise/promise (32).jpg
#   inflating: Word/Promise/promise (33).jpg
#   inflating: Word/Promise/promise (34).jpg
#   inflating: Word/Promise/promise (35).jpg
#   inflating: Word/Promise/promise (36).jpg
#   inflating: Word/Promise/promise (37).jpg
#   inflating: Word/Promise/promise (38).jpg
#   inflating: Word/Promise/promise (39).jpg
#   inflating: Word/Promise/promise (4).jpg
#   inflating: Word/Promise/promise (40).jpg
#   inflating: Word/Promise/promise (41).jpg
#   inflating: Word/Promise/promise (42).jpg
#   inflating: Word/Promise/promise (43).jpg
#   inflating: Word/Promise/promise (44).jpg
#   inflating: Word/Promise/promise (45).jpg
#   inflating: Word/Promise/promise (46).jpg
#   inflating: Word/Promise/promise (47).jpg
#   inflating: Word/Promise/promise (48).jpg
#   inflating: Word/Promise/promise (49).jpg
#   inflating: Word/Promise/promise (5).jpg
#   inflating: Word/Promise/promise (50).jpg
#   inflating: Word/Promise/promise (51).jpg
#   inflating: Word/Promise/promise (52).jpg
#   inflating: Word/Promise/promise (53).jpg
#   inflating: Word/Promise/promise (54).jpg
#   inflating: Word/Promise/promise (55).jpg
#   inflating: Word/Promise/promise (56).jpg
#   inflating: Word/Promise/promise (57).jpg
#   inflating: Word/Promise/promise (58).jpg
#   inflating: Word/Promise/promise (59).jpg
#   inflating: Word/Promise/promise (6).jpg
#   inflating: Word/Promise/promise (60).jpg
#   inflating: Word/Promise/promise (61).jpg
#   inflating: Word/Promise/promise (62).jpg
#   inflating: Word/Promise/promise (63).jpg
#   inflating: Word/Promise/promise (64).jpg
#   inflating: Word/Promise/promise (65).jpg
#   inflating: Word/Promise/promise (66).jpg
#   inflating: Word/Promise/promise (67).jpg
#   inflating: Word/Promise/promise (68).jpg
#   inflating: Word/Promise/promise (69).jpg
#   inflating: Word/Promise/promise (7).jpg
#   inflating: Word/Promise/promise (70).jpg
#   inflating: Word/Promise/promise (71).jpg
#   inflating: Word/Promise/promise (72).jpg
#   inflating: Word/Promise/promise (73).jpg
#   inflating: Word/Promise/promise (74).jpg
#   inflating: Word/Promise/promise (75).jpg
#   inflating: Word/Promise/promise (76).jpg
#   inflating: Word/Promise/promise (77).jpg
#   inflating: Word/Promise/promise (78).jpg
#   inflating: Word/Promise/promise (79).jpg
#   inflating: Word/Promise/promise (8).jpg
#   inflating: Word/Promise/promise (80).jpg
#   inflating: Word/Promise/promise (81).jpg
#   inflating: Word/Promise/promise (82).jpg
#   inflating: Word/Promise/promise (83).jpg
#   inflating: Word/Promise/promise (84).jpg
#   inflating: Word/Promise/promise (85).jpg
#   inflating: Word/Promise/promise (86).jpg
#   inflating: Word/Promise/promise (87).jpg
#   inflating: Word/Promise/promise (88).jpg
#   inflating: Word/Promise/promise (89).jpg
#   inflating: Word/Promise/promise (9).jpg
#   inflating: Word/Promise/promise (90).jpg
#    creating: Word/Request/
#   inflating: Word/Request/request (1).jpg
#   inflating: Word/Request/request (10).jpg
#   inflating: Word/Request/request (100).jpg
#   inflating: Word/Request/request (101).jpg
#   inflating: Word/Request/request (102).jpg
#   inflating: Word/Request/request (103).jpg
#   inflating: Word/Request/request (104).jpg
#   inflating: Word/Request/request (105).jpg
#   inflating: Word/Request/request (11).jpg
#   inflating: Word/Request/request (12).jpg
#   inflating: Word/Request/request (13).jpg
#   inflating: Word/Request/request (14).jpg
#   inflating: Word/Request/request (15).jpg
#   inflating: Word/Request/request (16).jpg
#   inflating: Word/Request/request (17).jpg
#   inflating: Word/Request/request (18).jpg
#   inflating: Word/Request/request (19).jpg
#   inflating: Word/Request/request (2).jpg
#   inflating: Word/Request/request (20).jpg
#   inflating: Word/Request/request (21).jpg
#   inflating: Word/Request/request (22).jpg
#   inflating: Word/Request/request (23).jpg
#   inflating: Word/Request/request (24).jpg
#   inflating: Word/Request/request (25).jpg
#   inflating: Word/Request/request (26).jpg
#   inflating: Word/Request/request (27).jpg
#   inflating: Word/Request/request (28).jpg
#   inflating: Word/Request/request (29).jpg
#   inflating: Word/Request/request (3).jpg
#   inflating: Word/Request/request (30).jpg
#   inflating: Word/Request/request (31).jpg
#   inflating: Word/Request/request (32).jpg
#   inflating: Word/Request/request (33).jpg
#   inflating: Word/Request/request (34).jpg
#   inflating: Word/Request/request (35).jpg
#   inflating: Word/Request/request (36).jpg
#   inflating: Word/Request/request (37).jpg
#   inflating: Word/Request/request (38).jpg
#   inflating: Word/Request/request (39).jpg
#   inflating: Word/Request/request (4).jpg
#   inflating: Word/Request/request (40).jpg
#   inflating: Word/Request/request (41).jpg
#   inflating: Word/Request/request (42).jpg
#   inflating: Word/Request/request (43).jpg
#   inflating: Word/Request/request (44).jpg
#   inflating: Word/Request/request (45).jpg
#   inflating: Word/Request/request (46).jpg
#   inflating: Word/Request/request (47).jpg
#   inflating: Word/Request/request (48).jpg
#   inflating: Word/Request/request (49).jpg
#   inflating: Word/Request/request (5).jpg
#   inflating: Word/Request/request (50).jpg
#   inflating: Word/Request/request (51).jpg
#   inflating: Word/Request/request (52).jpg
#   inflating: Word/Request/request (53).jpg
#   inflating: Word/Request/request (54).jpg
#   inflating: Word/Request/request (55).jpg
#   inflating: Word/Request/request (56).jpg
#   inflating: Word/Request/request (57).jpg
#   inflating: Word/Request/request (58).jpg
#   inflating: Word/Request/request (59).jpg
#   inflating: Word/Request/request (6).jpg
#   inflating: Word/Request/request (60).jpg
#   inflating: Word/Request/request (61).jpg
#   inflating: Word/Request/request (62).jpg
#   inflating: Word/Request/request (63).jpg
#   inflating: Word/Request/request (64).jpg
#   inflating: Word/Request/request (65).jpg
#   inflating: Word/Request/request (66).jpg
#   inflating: Word/Request/request (67).jpg
#   inflating: Word/Request/request (68).jpg
#   inflating: Word/Request/request (69).jpg
#   inflating: Word/Request/request (7).jpg
#   inflating: Word/Request/request (70).jpg
#   inflating: Word/Request/request (71).jpg
#   inflating: Word/Request/request (72).jpg
#   inflating: Word/Request/request (73).jpg
#   inflating: Word/Request/request (74).jpg
#   inflating: Word/Request/request (75).jpg
#   inflating: Word/Request/request (76).jpg
#   inflating: Word/Request/request (77).jpg
#   inflating: Word/Request/request (78).jpg
#   inflating: Word/Request/request (79).jpg
#   inflating: Word/Request/request (8).jpg
#   inflating: Word/Request/request (80).jpg
#   inflating: Word/Request/request (81).jpg
#   inflating: Word/Request/request (82).jpg
#   inflating: Word/Request/request (83).jpg
#   inflating: Word/Request/request (84).jpg
#   inflating: Word/Request/request (85).jpg
#   inflating: Word/Request/request (86).jpg
#   inflating: Word/Request/request (87).jpg
#   inflating: Word/Request/request (88).jpg
#   inflating: Word/Request/request (89).jpg
#   inflating: Word/Request/request (9).jpg
#   inflating: Word/Request/request (90).jpg
#   inflating: Word/Request/request (91).jpg
#   inflating: Word/Request/request (92).jpg
#   inflating: Word/Request/request (93).jpg
#   inflating: Word/Request/request (94).jpg
#   inflating: Word/Request/request (95).jpg
#   inflating: Word/Request/request (96).jpg
#   inflating: Word/Request/request (97).jpg
#   inflating: Word/Request/request (98).jpg
#   inflating: Word/Request/request (99).jpg
#    creating: Word/Salam/
#   inflating: Word/Salam/salam (1).jpg
#   inflating: Word/Salam/salam (10).jpg
#   inflating: Word/Salam/salam (11).jpg
#   inflating: Word/Salam/salam (12).jpg
#   inflating: Word/Salam/salam (13).jpg
#    creating: Word/Think/
#   inflating: Word/Think/think (1).jpg
#   inflating: Word/Think/think (10).jpg
#   inflating: Word/Think/think (100).jpg
#   inflating: Word/Think/think (101).jpg
#   inflating: Word/Think/think (102).jpg
#   inflating: Word/Think/think (103).jpg
#   inflating: Word/Think/think (104).jpg
#   inflating: Word/Think/think (105).jpg
#   inflating: Word/Think/think (106).jpg
#   inflating: Word/Think/think (11).jpg
#   inflating: Word/Think/think (12).jpg
#   inflating: Word/Think/think (13).jpg
#   inflating: Word/Think/think (14).jpg
#   inflating: Word/Think/think (15).jpg
#   inflating: Word/Think/think (16).jpg
#   inflating: Word/Think/think (17).jpg
#   inflating: Word/Think/think (18).jpg
#   inflating: Word/Think/think (19).jpg
#   inflating: Word/Think/think (2).jpg
#   inflating: Word/Think/think (20).jpg
#   inflating: Word/Think/think (21).jpg
#   inflating: Word/Think/think (22).jpg
#   inflating: Word/Think/think (23).jpg
#   inflating: Word/Think/think (24).jpg
#   inflating: Word/Think/think (25).jpg
#   inflating: Word/Think/think (26).jpg
#   inflating: Word/Think/think (27).jpg
#   inflating: Word/Think/think (28).jpg
#   inflating: Word/Think/think (29).jpg
#   inflating: Word/Think/think (3).jpg
#   inflating: Word/Think/think (30).jpg
#   inflating: Word/Think/think (31).jpg
#   inflating: Word/Think/think (32).jpg
#   inflating: Word/Think/think (33).jpg
#   inflating: Word/Think/think (34).jpg
#   inflating: Word/Think/think (35).jpg
#   inflating: Word/Think/think (36).jpg
#   inflating: Word/Think/think (37).jpg
#   inflating: Word/Think/think (38).jpg
#   inflating: Word/Think/think (39).jpg
#   inflating: Word/Think/think (4).jpg
#   inflating: Word/Think/think (40).jpg
#   inflating: Word/Think/think (41).jpg
#   inflating: Word/Think/think (42).jpg
#   inflating: Word/Think/think (43).jpg
#   inflating: Word/Think/think (44).jpg
#   inflating: Word/Think/think (45).jpg
#   inflating: Word/Think/think (46).jpg
#   inflating: Word/Think/think (47).jpg
#   inflating: Word/Think/think (48).jpg
#   inflating: Word/Think/think (49).jpg
#   inflating: Word/Think/think (5).jpg
#   inflating: Word/Think/think (50).jpg
#   inflating: Word/Think/think (51).jpg
#   inflating: Word/Think/think (52).jpg
#   inflating: Word/Think/think (53).jpg
#   inflating: Word/Think/think (54).jpg
#   inflating: Word/Think/think (55).jpg
#   inflating: Word/Think/think (56).jpg
#   inflating: Word/Think/think (57).jpg
#   inflating: Word/Think/think (58).jpg
#   inflating: Word/Think/think (59).jpg
#   inflating: Word/Think/think (6).jpg
#   inflating: Word/Think/think (60).jpg
#   inflating: Word/Think/think (61).jpg
#   inflating: Word/Think/think (62).jpg
#   inflating: Word/Think/think (63).jpg
#   inflating: Word/Think/think (64).jpg
#   inflating: Word/Think/think (65).jpg
#   inflating: Word/Think/think (66).jpg
#   inflating: Word/Think/think (67).jpg
#   inflating: Word/Think/think (68).jpg
#   inflating: Word/Think/think (69).jpg
#   inflating: Word/Think/think (7).jpg
#   inflating: Word/Think/think (70).jpg
#   inflating: Word/Think/think (71).jpg
#   inflating: Word/Think/think (72).jpg
#   inflating: Word/Think/think (73).jpg
#   inflating: Word/You/you (57).jpg
#   inflating: Word/You/you (58).jpg
#   inflating: Word/You/you (59).jpg
#   inflating: Word/You/you (6).jpg
#   inflating: Word/You/you (60).jpg
#   inflating: Word/You/you (61).jpg
#   inflating: Word/You/you (62).jpg
#   inflating: Word/You/you (63).jpg
#   inflating: Word/You/you (64).jpg
#   inflating: Word/You/you (65).jpg
#   inflating: Word/You/you (66).jpg
#   inflating: Word/You/you (67).jpg
#   inflating: Word/You/you (68).jpg
#   inflating: Word/You/you (69).jpg
#   inflating: Word/You/you (7).jpg
#   inflating: Word/You/you (70).jpg
#   inflating: Word/You/you (71).jpg
#   inflating: Word/You/you (72).jpg
#   inflating: Word/You/you (73).jpg
#   inflating: Word/You/you (74).jpg
#   inflating: Word/You/you (75).jpg
#   inflating: Word/You/you (76).jpg
#   inflating: Word/You/you (77).jpg
#   inflating: Word/You/you (78).jpg
#   inflating: Word/You/you (79).jpg
#   inflating: Word/You/you (8).jpg
#   inflating: Word/You/you (80).jpg
#   inflating: Word/You/you (81).jpg
#   inflating: Word/You/you (82).jpg
#   inflating: Word/You/you (83).jpg
#   inflating: Word/You/you (84).jpg
#   inflating: Word/You/you (85).jpg
#   inflating: Word/You/you (86).jpg
#   inflating: Word/You/you (87).jpg
#   inflating: Word/You/you (88).jpg
#   inflating: Word/You/you (89).jpg
#   inflating: Word/You/you (9).jpg
#   inflating: Word/You/you (90).jpg
#   inflating: Word/You/you (91).jpg
#   inflating: Word/You/you (92).jpg
#   inflating: Word/You/you (93).jpg
#   inflating: Word/You/you (94).jpg
#   inflating: Word/You/you (95).jpg
#   inflating: Word/You/you (96).jpg
#   inflating: Word/You/you (97).jpg
#   inflating: Word/You/you (98).jpg

# %%
base_path = '/content/Word'

# %%
SIZE = 224
image_size = (SIZE, SIZE)
batch_size = 32
channels = 3
kernel = 4
stride = 1
pool = 2

# %%
#show resized images
img = cv2.imread("/content/Word/Myself/myself (55).jpg")[:, :, ::-1]
width, height = SIZE, SIZE
resized_img = cv2.resize(img, (width, height))
plt.imshow(img)
plt.figure(figsize = (1.5, 1.5))
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (224, 224, 3)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    base_path,
    validation_split = 0.2,
    subset = "training",
    seed = 42,
    image_size = image_size,
    batch_size = batch_size,
)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    base_path,
    validation_split = 0.2,
    subset = "validation",
    seed = 42,
    image_size = image_size,
    batch_size = batch_size,
)
# Out:
# Found 992 files belonging to 10 classes.
# Using 794 files for training.
# Found 992 files belonging to 10 classes.
# Using 198 files for validation.

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    zoom_range = 0.2,
    shear_range = 0.2,
    horizontal_flip= True,
    vertical_flip= False,
    validation_split= 0.2,
)
test_datagen = ImageDataGenerator(
    rescale = 1./255,
    validation_split= 0.2,
)

# %%
train_set = train_datagen.flow_from_directory(
    base_path,
    target_size = image_size,
    batch_size = batch_size,
    class_mode= 'categorical',
    shuffle = True,
    subset = 'training'
)
test_set = train_datagen.flow_from_directory(
    base_path,
    target_size = image_size,
    batch_size = batch_size,
    class_mode= 'categorical',
    shuffle = False,
    subset = 'validation'
)
# Out:
# Found 796 images belonging to 10 classes.
# Found 196 images belonging to 10 classes.

# %%
test_set.class_indices
# Out:
# {'Color': 0,
#  'Friend': 1,
#  'Myself': 2,
#  'Promise': 3,
#  'Request': 4,
#  'Salam': 5,
#  'Surprise': 6,
#  'They': 7,
#  'Think': 8,
#  'You': 9}

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
class_names
# Out:
# ['Color',
#  'Friend',
#  'Myself',
#  'Promise',
#  'Request',
#  'Salam',
#  'Surprise',
#  'They',
#  'Think',
#  'You']

# %%
labels = ['Color','Friend','Myself','Promise','Request','Salam','Surprise','They','Think','You']

# %%
plt.figure(figsize=(10,10))
for image_batch, labels_batch in train_ds.take(1):
  for i in range(12):
    ax=plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[labels_batch[i]])
    plt.axis("off")

# %% [markdown]
# #MobileNet-V2 Model

# %%
Mobilenetv2 = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
for layer in Mobilenetv2.layers:
    layer.trainable = False

# %%
from tensorflow.keras import layers
standard_classifier = tf.keras.Sequential()
standard_classifier.add(layers.Flatten())
standard_classifier.add(layers.BatchNormalization())
standard_classifier.add(layers.Dense(100))
standard_classifier.add(layers.Activation('relu'))
standard_classifier.add(layers.Dense(10))
standard_classifier.add(layers.Activation('softmax'))

# %%
model = tf.keras.Sequential([
 Mobilenetv2,
  standard_classifier
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  sequential (Sequential)     (None, 10)                6523990
#
# =================================================================
# Total params: 8,781,974
# Trainable params: 6,398,550
# Non-trainable params: 2,383,424
# _________________________________________________________________

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (989 kB)
#      |████████████████████████████████| 989 kB 35.3 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.15 visualkeras-0.0.2

# %%
from PIL import ImageFont
import visualkeras
font = ImageFont.truetype("/content/drive/MyDrive/Sign Language Project/RobotoSlab-VariableFont_wght.ttf", 12)
visualkeras.layered_view(model, legend=True, font=font)
# Out:
# <PIL.Image.Image image mode=RGBA size=186x116 at 0x7F3EF0501CD0>

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
history = model.fit(
  train_set,
  validation_data=test_set,
  epochs=25,
  steps_per_epoch=len(train_set),
  validation_steps=len(test_set),
  callbacks=model_checkpoint,
)
# Out:
# Epoch 1/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.1199 - accuracy: 0.9925 - val_loss: 6.3188 - val_accuracy: 0.8571
# Epoch 2/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.1637 - accuracy: 0.9887 - val_loss: 3.0281 - val_accuracy: 0.8878
# Epoch 3/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.1598 - accuracy: 0.9887 - val_loss: 4.5783 - val_accuracy: 0.8622
# Epoch 4/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.3396 - accuracy: 0.9824 - val_loss: 3.8762 - val_accuracy: 0.8929
# Epoch 5/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.3817 - accuracy: 0.9849 - val_loss: 3.6588 - val_accuracy: 0.8929
# Epoch 6/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.6803 - accuracy: 0.9761 - val_loss: 4.9243 - val_accuracy: 0.8724
# Epoch 7/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.2116 - accuracy: 0.9849 - val_loss: 6.5631 - val_accuracy: 0.8673
# Epoch 8/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.1493 - accuracy: 0.9912 - val_loss: 5.9588 - val_accuracy: 0.8673
# Epoch 9/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.2269 - accuracy: 0.9874 - val_loss: 5.7807 - val_accuracy: 0.8673
# Epoch 10/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.2826 - accuracy: 0.9874 - val_loss: 5.5768 - val_accuracy: 0.8980
# Epoch 11/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.1627 - accuracy: 0.9912 - val_loss: 3.7030 - val_accuracy: 0.9082
# Epoch 12/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.2154 - accuracy: 0.9937 - val_loss: 5.0177 - val_accuracy: 0.8673
# Epoch 13/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.2025 - accuracy: 0.9899 - val_loss: 6.7112 - val_accuracy: 0.8673
# Epoch 14/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.2326 - accuracy: 0.9912 - val_loss: 5.3846 - val_accuracy: 0.8878
# Epoch 15/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.1026 - accuracy: 0.9874 - val_loss: 7.5063 - val_accuracy: 0.8418
# Epoch 16/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.0278 - accuracy: 0.9987 - val_loss: 4.9524 - val_accuracy: 0.8929
# Epoch 17/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.1517 - accuracy: 0.9925 - val_loss: 5.6769 - val_accuracy: 0.8776
# Epoch 18/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.0362 - accuracy: 0.9975 - val_loss: 7.1758 - val_accuracy: 0.8673
# Epoch 19/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.0396 - accuracy: 0.9962 - val_loss: 4.2376 - val_accuracy: 0.8878
# Epoch 20/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.2458 - accuracy: 0.9912 - val_loss: 5.3853 - val_accuracy: 0.8776
# Epoch 21/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.0594 - accuracy: 0.9937 - val_loss: 5.3625 - val_accuracy: 0.8878
# Epoch 22/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.1081 - accuracy: 0.9937 - val_loss: 4.8567 - val_accuracy: 0.8980
# Epoch 23/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.0833 - accuracy: 0.9925 - val_loss: 4.4769 - val_accuracy: 0.8980
# Epoch 24/25
# 25/25 [==============================] - 120s 5s/step - loss: 0.0586 - accuracy: 0.9975 - val_loss: 6.1283 - val_accuracy: 0.8827
# Epoch 25/25
# 25/25 [==============================] - 121s 5s/step - loss: 0.1036 - accuracy: 0.9937 - val_loss: 7.6455 - val_accuracy: 0.8571

# %%
# Validation and Training accuracy plot
import matplotlib.pyplot as plt

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
#Validation and Training loss plot
fig = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(image_batch[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for image_batch, labels_batch in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        predicted_class, confidence =predict(model, image_batch[i].numpy())
        actual_class = class_names[labels_batch[i]] 
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")

# %%
loss,test_accuracy = model.evaluate(test_set)
print('Accuracy on test:', test_accuracy)
# Out:
# 7/7 [==============================] - 27s 4s/step - loss: 5.3304 - accuracy: 0.8827
# Accuracy on test: 0.8826530575752258

# %%
# T0 print the Classification Report
y_pred = model.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
print(classification_report(test_set.classes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        18
#            1       0.91      1.00      0.95        20
#            2       0.94      0.81      0.87        21
#            3       1.00      1.00      1.00        18
#            4       0.60      0.86      0.71        21
#            5       0.83      1.00      0.90        19
#            6       0.90      0.95      0.93        20
#            7       0.83      0.79      0.81        19
#            8       1.00      0.95      0.98        21
#            9       1.00      0.37      0.54        19
#
#     accuracy                           0.87       196
#    macro avg       0.90      0.87      0.87       196
# weighted avg       0.89      0.87      0.87       196

# %%
import seaborn as sns
# To print the Confusion Matrix
cf_matrix = confusion_matrix(test_set.classes, y_pred)
labels = ['Color','Friend','Myself','Promise','Request','Salam','Surprise','They','Think','You']
plt.figure(figsize=(8, 8))
heatmap = sns.heatmap(cf_matrix, xticklabels=labels, yticklabels=labels, annot=True, fmt='d', color='blue')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Confusion Matrix')
plt.show()
